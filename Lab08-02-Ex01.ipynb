// %% [markdown]
// # Lab 8 Exercise 1
// ##  การสร้าง Class

// %% [markdown]
// 1. สร้าง console application project

// %% [markdown]
// 1.1 เรียก terminal (cmd) ขึ้นมา
//
// 1.2 ตรวจสอบให้แน่ใจว่าอยู่ใน folder หรือ directory ที่ต้องการสร้าง project
//
// 1.3 พิมพ์คำสั่งต่อไปนี้
//
// ```
//     dotnet new console --name Lab08_Ex01
// ```
//
// 1.4 ใช้คำสั่ง dir เพื่อตรวจสอบดูว่าโฟลเดอร์ของ project ได้ถูกสร้างขึ้นแล้วหรือยัง

// %% [markdown]
// 2. เปลี่ยน code ในไฟล์ program.cs ให้เป็นดังต่อไปนี้ (ตัวเลขข้างหน้า คือหมายเลขบรรทัด ไว้สำหรับอ้างอิง)
//
// > ```c#
// > 1.  Person p = new Person();
// > 2.  System.Console.WriteLine($"Type of p is {p.GetType()}");
// > 3.
// > 4.  class Person
// > 5.  {
// > 6.
// > 7.  }
// > ```

// %% [markdown]
// 3. Build project โดยการใช้คำสั่ง
//
// ```
// dotnet build  Lab08_Ex01
// ```

// %% [markdown]
// 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5. Run project โดยการใช้คำสั่ง
//
// ```
// dotnet run --project Lab08_Ex01
// ```

// %% [markdown]
// 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7. โค้ดต่อไปนี้สามารถรันได้ใน polyglot notebook หรือไม่

// %%
Person p = new Person();
System.Console.WriteLine($"Type of p is {p.GetType()}");

class Person
{

}
// Out:
// Type of p is Submission#1+Person

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// สามารถรันโค้ดได้

// %% [markdown]
// ## คำถาม

// %% [markdown]
// 1. Class ในภาษา C# คืออะไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// lass คือแม่แบบ  สำหรับสร้างอ็อบเจ็กต์  ในภาษา C# โดยกำหนดโครงสร้างของข้อมูลและพฤติกรรมของอ็อบเจ็กต์

// %% [markdown]
// 2. Class มีหน้าที่อะไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// lass มีหน้าที่กำหนดโครงสร้างของอ็อบเจ็กต์

// %% [markdown]
// 3. ทำไมเราต้องใช้ Class

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// Class ช่วยให้การเขียนโปรแกรมเป็นระเบียบ แบ่งโครงสร้างของโปรแกรมออกเป็นโมดูล สามารถนำกลับมาใช้ซ้ำได้

// %% [markdown]
// 4. ส่วนประกอบของ Class มีอะไรบ้าง

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// Fields
//
// Properties
//
// Methods
//
// Constructors
//
// Events

// %% [markdown]
// 5. Class และ Object แตกต่างกันอย่างไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// Class คือแม่แบบสำหรับสร้างอ็อบเจ็กต์
//
// Object คืออินสแตนซ์ ของ Class ที่ถูกสร้างขึ้นมาและสามารถใช้งานได้จริง

// %% [markdown]
// 6. การตั้งชื่อ Class มีหลักเกณฑ์อย่างไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// หลีกเลี่ยงการใช้คำสงวนของ C#
// ต้องขึ้นต้นด้วยตัวอักษรและสามารถมีตัวเลขหรืออักขระพิเศษ (_) ได้

// %% [markdown]
// 7. คำสั่ง p.GetType() คืออะไร

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// p.GetType() ใช้สำหรับคืนค่าประเภท (Type) ของอ็อบเจ็กต์ p ในขณะรันไทม์

// %% [markdown]
// 8. ผลที่ได้จากคำสั่ง  p.GetType() คืออะไร มันให้ข้อมูลอะไรแก่เราบ้าง

// %% [markdown]
// *คำตอบ*

// %% [markdown]
// คำสั่ง p.GetType() คืนค่าเป็น System.Type ที่ให้ข้อมูลเกี่ยวกับประเภทของอ็อบเจ็กต์ เช่น ชื่อคลาส

// %% [markdown]
// 9. ในภาษา C# การประกาศ class ไว้ก่อนหรือหลังการสร้าง  object ต่างกันหรือไม่

// %% [markdown]
// การประกาศ Class ต้องมาก่อนการสร้าง Object เสมอ ไม่สามารถสร้าง Object จาก Class ที่ยังไม่ได้ประกาศได้ เพราะในขั้นตอนคอมไพล์ โปรแกรมต้องรู้จักชนิดของคลาสก่อนจึงจะสามารถสร้างอินสแตนซ์ (Object) ได้

// %% [markdown]
// *คำตอบ*
